# %%
import pandas as pd

# %%
df=pd.read_csv('diabetes_knn.csv')

# %%
X=df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]

# %%
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)    # find out min & max value
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
#Using Hyperparameter tunning
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
params = {'n_estimators':[50,60,70,80],'learning_rate':[0.6,0.7,0.8,0.9,1]}

# %%
grid_cv = GridSearchCV(AdaBoostClassifier(),param_grid=params,cv=5,verbose=3)
